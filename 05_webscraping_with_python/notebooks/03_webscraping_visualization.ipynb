# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Web Scraping mit [Python](https://www.python.org/) mit [`BeautifulSoup`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) und [`requests`](https://2.python-requests.org/en/master/)

# %% [markdown]
# ## Visualisierung

# %% [markdown]
# __Importieren von Python Bibliotheken__

# %%
from bs4 import BeautifulSoup
import requests
import sys

# %% [markdown]
# **Add path to look for modules**

# %%
import sys
sys.path.append("../src")

# %%
import get_blog_urls, get_text

# %% [markdown]
# ### Festlegen der URL

# %%
base_url = "https://www.beiersdorf.de/"
blog_url = "beiersdorf-live/karriere-blog/blog-uebersicht"

# %% [markdown]
# ### Extrahieren aller Links zu den Blogeinträgen

# %%
import numpy as np 
loadCounts = np.arange(0, 100, 12)
loadCounts
# Out:
# array([ 0, 12, 24, 36, 48, 60, 72, 84, 96])

# %%
blog_urls = [blog_url+f'?loadCount={i}' for i in loadCounts]

# %%
hyper_links = get_blog_urls.get_blog_urls(base_url, blog_urls)
# Out:
# 75 links to articles were found!

# %% [markdown]
# > Falls die vorherige Zelle nicht funktioniert, können Sie die folgende Zelle ausführen (von `Raw` auf `Code` ändern):

# %% [raw]
# import pickle
# hyper_links = pickle.load(open ('../src/_solutions/hyper_links_02.p', 'rb'))

# %% [markdown]
# ### Extrahieren aller Textelemente und aller Blogartikel

# %%
blog_texts = get_text.get_text(urls=hyper_links)
# Out:
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2019/03/06-die-digitalisierung-fuer-kindergaerten-wertvoll-gestalten
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/04/16-meine-ersten-6-tage-bei-beiersdorf-nigeria-von-abosede-adeniran
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/04/2016-04-06-welcome-to-hamburg
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/04/06-die-menschen-hinter-unseren-produkten-anil-yumut
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/08/29-die-geburt-eines-thronfolgers-nivea-deo-crown
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/02/03-willkommen-in-china
# Extracting https://www.beiersdorf.de/investoren/finanzberichte/finanzpublikationen
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/10/13-die-menschen-hinter-unseren-produkten-anita-motta
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/05/31-wichtige-erkenntnisse-fuer-die-hautkrebs-forschung
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/08/10-mission-zukunft-inspiration-silicon-valley
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/04/2016-04-07-die-menschen-hinter-unseren-produkten-sachin-killawala
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/07/25-manchmal-muss-man-eben-ins-kalte-wasser-springen
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/06/08-internationaler-tag-der-umwelt-we-care-bei-beiersdorf-in-brasilien
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/09/05-sentuhan-ibu-nivea-indonesia
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/01/2016-01-26-sawubona-south-africa
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/05/2016-05-06-die-menschen-hinter-unseren-produkten-zhong-xiao
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/01/30-internationale-women-in-leadership-convention-bei-beiersdorf
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/11/13-herausforderung-angenommen-beiersdorf-internship-challenge-erneut-riesen-erfolg
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/10/17-wilkommen-in-den-usa
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2019/04/04-augmented-reality-das-naechste-format-des-storytellings
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2019/02/13-nivea-hebt-das-crowdsourcing-auf-ein-neues-level
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/10/10-die-menschen-hinter-unseren-produkten-josep-picas
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/04/30-dirk-ploss-interview
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/08/15-muttertag-nivea-thailand
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/07/02-arbeitsleidenschaft-in-ecuador
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/08/10-mehr-als-nur-zahlen-finance-goes-beyond
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/08/25-die-nivea-hair-always-on-kampagne
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2019/05/08-austausch-trifft-erfindergeist
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/07/26-ein-job-mit-mehrwert
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2019/05/28-freedom-to-innovate-arbeiten-wie-in-einem-start-up
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/04/21-film-ab-fuer-die-naechste-generation
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2019/05/22-101-tage-kwesi
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/08/31-new-york-new-york-und-film-ab
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/04/12-dr-ruppert-rockt-8x4-tv-spot
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/09/06-willkommen-in-italien
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/09/01-von-praktikanten-fuer-praktikanten
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/03/2016-03-10-beiersdorf-blueplanet
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/02/09-arbeiten-in-singapur
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/10/12-interview-mit-marielen-winter
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/03/14-content-marketing-nivea-vom-buzzword-zum-business
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2015/11/2015-11-20-sao-paolo-november
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/06/23-das-blaue-wunder-nivea
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/09/08-blau-weiss
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/07/13-bluenet-app
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/02/28-hallo-hongkong
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/01/2016-01-22-my-cross-company-career
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/08/31-nivea-sun-lotte-und-max
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/11/01-Sharing-is-caring
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/01/2016-01-28-duo-award
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2019/05/17-eine-aktive-rolle-im-recruiting-einnehmen
# Extracting https://www.beiersdorf.de/ueber-uns/beiersdorf-global
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/04/27-beyond-international-careers
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/07/20-die-menschen-hinter-unseren-produkten-nele-marie-bock
# Extracting https://www.beiersdorf.de/karriere/jobsuche/jobsuche
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/11/14-Von-Mailand-nach-Manila
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2019/05/02-wir-muessen-wie-ein-startup-agieren
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/08/01-8x4-spray-and-play-challenge
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/05/04-die-menschen-hinter-unseren-produkten-leonid-zaplatnikov
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/06/2016-06-14-die-menschen-hinter-unseren-produkten-marc-winnefeld
# Extracting https://www.beiersdorf.de/marken/nivea
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/08/30-beiersdorf-gruendet-tochtergesellschaft-in-kairo
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/07/13-die-menschen-hinter-unseren-produkten-marina-shlyaptseva
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/05/17-beiersdorf-international-internship-challenge-2017
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/03/06-die-menschen-hinter-unseren-produkten-annika-schuepfer
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/09/14-die-menschen-hinter-unseren-produkten-timo-seidel
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/01/24-aufbruchsstimmung-go-beyond
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/01/24-skin-hack-2-0-hier-schwitzt-der-tech-nachwuchs
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/11/14-wir-erarbeiten-taeglich-einen-wettbewerbsvorteil
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/04/26-nivea-cares-for-family-suedafrika
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/09/26-virtuelle-reise-durch-die-haut
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2016/08/25-die-komfortzone-verlassen
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/03/07-the-influencer-movement-nivea
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2017/05/31-kuenstliche-intelligenz-in-der-hautpflege
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/06/20-mach-mit-beim-nivea-men-barbiershop-talk
# Extracting https://www.beiersdorf.de/beiersdorf-live/karriere-blog/blog-uebersicht/2018/10/22-faszinierend-spannend-divers-ein-halbes-jahr-in-suedafrika
#
# Dowload complete!

# %% [markdown]
# > Falls die vorherige Zelle nicht funktioniert, können Sie die folgende Zelle ausführen (von `Raw` auf `Code` ändern):

# %% [raw]
# import pickle
# blog_texts = pickle.load(open ('../src/_solutions/blog_texts_03.p', 'rb'))

# %%
len(blog_texts)
# Out:
# 75

# %% [markdown]
# ### Zusammenführen aller Texte in einen Text

# %%
full_blog_texts = ''.join(blog_texts)
len(full_blog_texts)
# Out:
# 210822

# %%
#full_blog_texts

# %%
len(full_blog_texts.split(' '))
# Out:
# 29715

# %%
from IPython.display import IFrame    
url = 'https://i2.wp.com/electricliterature.com/wp-content/uploads/2014/07/0*HIkNNJkRFzb9CoPG.jpg?zoom=2&w=640&ssl=1'
IFrame(url, width='100%', height=400)
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://i2.wp.com/electricliterature.com/wp-content/uploads/2014/07/0*HIkNNJkRFzb9CoPG.jpg?zoom=2&w=640&ssl=1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Visualisierung

# %%
from wordcloud import WordCloud

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Schlagwortwolke 1

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(full_blog_texts)


# Display the generated image:
fig, ax = plt.subplots(figsize=(12,6))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off");

# %% [markdown]
# > __Problem:__
# * Was ist das Problem mit der Schlagwortwolke?

# %% [markdown]
# ### Schlagwortwolke 2

# %%
stopwords=["a","ab","aber","ach","acht","achte","achten","achter","achtes","ag","alle","allein","allem","allen","aller","allerdings","alles","allgemeinen","als","also","am","an","ander","andere","anderem","anderen","anderer","anderes","anderm","andern","anderr","anders","au","auch","auf","aus","ausser","ausserdem","außer","außerdem","b","bald","bei","beide","beiden","beim","beispiel","bekannt","bereits","besonders","besser","besten","bin","bis","bisher","bist","c","d","d.h","da","dabei","dadurch","dafür","dagegen","daher","dahin","dahinter","damals","damit","danach","daneben","dank","dann","daran","darauf","daraus","darf","darfst","darin","darum","darunter","darüber","das","dasein","daselbst","dass","dasselbe","davon","davor","dazu","dazwischen","daß","dein","deine","deinem","deinen","deiner","deines","dem","dementsprechend","demgegenüber","demgemäss","demgemäß","demselben","demzufolge","den","denen","denn","denselben","der","deren","derer","derjenige","derjenigen","dermassen","dermaßen","derselbe","derselben","des","deshalb","desselben","dessen","deswegen","dich","die","diejenige","diejenigen","dies","diese","dieselbe","dieselben","diesem","diesen","dieser","dieses","dir","doch","dort","drei","drin","dritte","dritten","dritter","drittes","du","durch","durchaus","durfte","durften","dürfen","dürft","e","eben","ebenso","ehrlich","ei","ei,","eigen","eigene","eigenen","eigener","eigenes","ein","einander","eine","einem","einen","einer","eines","einig","einige","einigem","einigen","einiger","einiges","einmal","eins","elf","en","ende","endlich","entweder","er","ernst","erst","erste","ersten","erster","erstes","es","etwa","etwas","euch","euer","eure","eurem","euren","eurer","eures","f","folgende","früher","fünf","fünfte","fünften","fünfter","fünftes","für","g","gab","ganz","ganze","ganzen","ganzer","ganzes","gar","gedurft","gegen","gegenüber","gehabt","gehen","geht","gekannt","gekonnt","gemacht","gemocht","gemusst","genug","gerade","gern","gesagt","geschweige","gewesen","gewollt","geworden","gibt","ging","gleich","gott","gross","grosse","grossen","grosser","grosses","groß","große","großen","großer","großes","gut","gute","guter","gutes","h","hab","habe","haben","habt","hast","hat","hatte","hatten","hattest","hattet","heisst","her","heute","hier","hin","hinter","hoch","hätte","hätten","i","ich","ihm","ihn","ihnen","ihr","ihre","ihrem","ihren","ihrer","ihres","im","immer","in","indem","infolgedessen","ins","irgend","ist","j","ja","jahr","jahre","jahren","je","jede","jedem","jeden","jeder","jedermann","jedermanns","jedes","jedoch","jemand","jemandem","jemanden","jene","jenem","jenen","jener","jenes","jetzt","k","kam","kann","kannst","kaum","kein","keine","keinem","keinen","keiner","keines","kleine","kleinen","kleiner","kleines","kommen","kommt","konnte","konnten","kurz","können","könnt","könnte","l","lang","lange","leicht","leide","lieber","los","m","machen","macht","machte","mag","magst","mahn","mal","man","manche","manchem","manchen","mancher","manches","mann","mehr","mein","meine","meinem","meinen","meiner","meines","mensch","menschen","mich","mir","mit","mittel","mochte","mochten","morgen","muss","musst","musste","mussten","muß","mußt","möchte","mögen","möglich","mögt","müssen","müsst","müßt","n","na","nach","nachdem","nahm","natürlich","neben","nein","neue","neuen","neun","neunte","neunten","neunter","neuntes","nicht","nichts","nie","niemand","niemandem","niemanden","noch","nun","nur","o","ob","oben","oder","offen","oft","ohne","ordnung","p","q","r","recht","rechte","rechten","rechter","rechtes","richtig","rund","s","sa","sache","sagt","sagte","sah","satt","schlecht","schluss","schon","sechs","sechste","sechsten","sechster","sechstes","sehr","sei","seid","seien","sein","seine","seinem","seinen","seiner","seines","seit","seitdem","selbst","sich","sie","sieben","siebente","siebenten","siebenter","siebentes","sind","so",'sogar',"solang","solche","solchem","solchen","solcher","solches","soll","sollen","sollst","sollt","sollte","sollten","sondern","sonst","soweit","sowie","später","startseite","statt","steht","suche","t","tag","tage","tagen","tat","teil","tel","tritt","trotzdem","tun","u","uhr","um","und","und?","uns","unse","unsem","unsen","unser","unsere","unserer","unses","unter","v","vergangenen","viel","viele","vielem","vielen","vielleicht","vier","vierte","vierten","vierter","viertes","vom","von","vor","w","wahr?","wann","war","waren","warst","wart","warum","was","weg","wegen","weil","weit","weiter","weitere","weiteren","weiteres","welche","welchem","welchen","welcher","welches","wem","wen","wenig","wenige","weniger","weniges","wenigstens","wenn","wer","werde","werden","werdet","weshalb","wessen","wie","wieder","wieso","will","willst","wir","wird","wirklich","wirst","wissen","wo","woher","wohin","wohl","wollen","wollt","wollte","wollten","worden","wurde","wurden","während","währenddem","währenddessen","wäre","würde","würden","x","y","z","z.b","zehn","zehnte","zehnten","zehnter","zehntes","zeit","zu","zuerst","zugleich","zum","zunächst","zur","zurück","zusammen","zwanzig","zwar","zwei","zweite","zweiten","zweiter","zweites","zwischen","zwölf",'unseren',"über","überhaupt","übrigens"]

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud(stopwords=stopwords).generate(full_blog_texts)


# Display the generated image:
fig, ax = plt.subplots(figsize=(12,6))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off");

# %% [markdown]
# ### Schlagwortwolke 3
# > __Aufgabe:__
# > Spielen Sie ein wenig mit den Parametern der Funktion `WordCloud`. Hilfe finden sie unter `?WordCloud`.

# %%
#?WordCloud

# %%
## your code here ...

# %%
# %load ../src/_solutions/wordcloud3.py

# %% [markdown]
# ### Schlagwortwolke 4
# > __Aufgabe:__
# * Verwenden der Bildmaske `../data/images/world.png`

# %%
from PIL import Image
mask = np.array(Image.open("../data/images/world.png"))   #choose mask

## your code here ...

# %%
# %load ../src/_solutions/wordcloud4.py

# %% [markdown]
# ### Schlagwortwolke 5
# > __Erweiterung:__
# * Verwenden einer Bildmaske `../data/images/Hamburg_Umriss.png`

# %%
from PIL import Image
mask = np.array(Image.open("../data/images/Hamburg_Umriss.png"))   #choose mask

## your code here ...

# %%
# %load ../src/_solutions/wordcloud5.py

# %% [markdown]
# ***
